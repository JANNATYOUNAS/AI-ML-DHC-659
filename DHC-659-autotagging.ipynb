# %%
# !pip install transformers datasets torch scikit-learn openai
# Out:
# Requirement already satisfied: transformers in d:\users\admin\anaconda3\lib\site-packages (4.55.2)
# Requirement already satisfied: datasets in d:\users\admin\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: torch in d:\users\admin\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: scikit-learn in d:\users\admin\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: openai in d:\users\admin\anaconda3\lib\site-packages (1.99.3)
# Requirement already satisfied: filelock in d:\users\admin\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in d:\users\admin\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\users\admin\anaconda3\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\users\admin\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in d:\users\admin\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in d:\users\admin\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\users\admin\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in d:\users\admin\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\users\admin\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\users\admin\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in d:\users\admin\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in d:\users\admin\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in d:\users\admin\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: scipy>=1.6.0 in d:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\users\admin\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\users\admin\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\users\admin\anaconda3\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\users\admin\anaconda3\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\users\admin\anaconda3\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in d:\users\admin\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in d:\users\admin\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\users\admin\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: certifi in d:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\users\admin\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in d:\users\admin\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\admin\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\admin\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\admin\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\admin\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in d:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import pandas as pd

# Load dataset
file_path = "C:\\Users\\Admin\\OneDrive\\Desktop\\customer_support_tickets.csv\\customer_support_tickets.csv"
df = pd.read_csv(file_path)

# Keep only necessary columns
df = df[["Ticket Description", "Ticket Type"]].dropna()

df.head()
# Out:
#                                   Ticket Description      Ticket Type
# 0  I'm having an issue with the {product_purchase...  Technical issue
# 1  I'm having an issue with the {product_purchase...  Technical issue
# 2  I'm facing a problem with my {product_purchase...  Technical issue
# 3  I'm having an issue with the {product_purchase...  Billing inquiry
# 4  I'm having an issue with the {product_purchase...  Billing inquiry

# %%
from transformers import pipeline

# Define classifier
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# Define candidate labels (categories from dataset)
candidate_labels = df["Ticket Type"].unique().tolist()
print("Candidate Labels:", candidate_labels)

# Test on a sample ticket
sample_ticket = df["Ticket Description"].iloc[0]
result = classifier(sample_ticket, candidate_labels, multi_label=False)

print("Ticket:", sample_ticket)
print("Top Predictions:", list(zip(result["labels"], result["scores"])))
# Out:
# WARNING:tensorflow:From D:\Users\Admin\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Device set to use cpu
# Candidate Labels: ['Technical issue', 'Billing inquiry', 'Cancellation request', 'Product inquiry', 'Refund request']
# Ticket: I'm having an issue with the {product_purchased}. Please assist.
#
# Your billing zip code is: 71701.
#
# We appreciate that you have requested a website address.
#
# Please double check your email address. I've tried troubleshooting steps mentioned in the user manual, but the issue persists.
# Top Predictions: [('Product inquiry', 0.40578052401542664), ('Billing inquiry', 0.34699854254722595), ('Technical issue', 0.19952958822250366), ('Refund request', 0.029203880578279495), ('Cancellation request', 0.018487442284822464)]

# %%
from sklearn.metrics import accuracy_score, top_k_accuracy_score

y_true = []
y_pred = []
all_probs = []

for desc, true_label in zip(df["Ticket Description"], df["Ticket Type"]):
    res = classifier(desc, candidate_labels, multi_label=False)
    y_true.append(true_label)
    y_pred.append(res["labels"][0])
    all_probs.append(res["scores"])

# Accuracy
acc = accuracy_score(y_true, y_pred)

# Top-3 Accuracy (manually check if true label is in top 3)
top3_correct = 0
for true, probs, labels in zip(y_true, all_probs, [classifier(d, candidate_labels)["labels"][:3] for d in df["Ticket Description"]]):
    if true in labels:
        top3_correct += 1
top3_acc = top3_correct / len(y_true)

print("Zero-Shot Accuracy:", round(acc, 3))
print("Zero-Shot Top-3 Accuracy:", round(top3_acc, 3))

# %%
args = TrainingArguments(
    output_dir="output",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=2,
    logging_dir="logs",
    logging_strategy="steps",   # <--- ensures logs appear
    logging_steps=10,           # <--- print every 10 steps
    load_best_model_at_end=True,
    metric_for_best_model="accuracy"
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=tokenizer,
)

train_result = trainer.train()
print(train_result)

# %%
from sklearn.metrics import classification_report, accuracy_score

# Get predictions
preds = trainer.predict(dataset["test"])
y_true = preds.label_ids
y_pred = np.argmax(preds.predictions, axis=1)

# Accuracy
acc = accuracy_score(y_true, y_pred)
print("Fine-Tuned Model Accuracy:", round(acc, 3))

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=labels))

# %%
import torch
import numpy as np

def get_top3_predictions(texts, model, tokenizer, labels, top_k=3):
    encodings = tokenizer(texts, truncation=True, padding=True, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**encodings)
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1).numpy()
    
    results = []
    for i, prob in enumerate(probs):
        top_indices = prob.argsort()[-top_k:][::-1]
        top_labels = [labels[j] for j in top_indices]
        top_probs = [round(prob[j], 3) for j in top_indices]
        results.append({"Ticket": texts[i], "Top_3_Predictions": list(zip(top_labels, top_probs))})
    return results

# Run on test set
test_texts = dataset["test"]["Ticket Description"]
top3_results = get_top3_predictions(test_texts, model, tokenizer, labels)

# Display first 5
for r in top3_results[:5]:
    print("Ticket:", r["Ticket"])
    for label, prob in r["Top_3_Predictions"]:
        print(f"  {label}: {prob}")
    print("-"*50)
